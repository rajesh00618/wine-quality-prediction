# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,accuracy_score
from sklearn.neighbors import KNeighborsRegressor

# %%
df=pd.read_csv('winequality-red.csv')

df.value_counts('quality')
df['quality'].nunique()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X=df.drop(columns='quality')
Y=df['quality']
X=df.drop(columns='quality')
Y=df['quality']
scaler=StandardScaler()
k=40
model=KNeighborsRegressor(n_neighbors=k)

X=scaler.fit_transform(X)
x_train,x_test,y_train,y_test=train_test_split(X,Y, test_size=0.2,random_state=10)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
mean_squared_error(y_test,y_pred)
new_sample=np.array([[7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4]])
l=model.predict(new_sample)
print(int(l))
# Out:
# 5

# %%
import matplotlib.pyplot as plt

# Scatter actual values (y_test) - shown as red dots
plt.scatter(range(len(y_test)), y_test, color='red', label='Actual (y_test)', marker='o')

# Scatter predicted values (y_pred) - shown as blue dots
plt.scatter(range(len(y_pred)), y_pred, color='blue', label='Predicted (y_pred)', marker='x')

# Labels and title
plt.xlabel("Sample Index")
plt.ylabel("Wine Quality")
plt.title("KNN Regression: Actual vs Predicted (Color Coded)")
plt.legend()
plt.grid(True)
plt.show()
